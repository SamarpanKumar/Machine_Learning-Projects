# %%
import pandas as pd

# %%
df1 = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns= ['A','B','C'])

# %%
df1
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df2 = pd.DataFrame([[11,2,33],[44,5,66],[77,8,99]], columns=['X','Y','Z'])

# %%
df2
# Out:
#     X  Y   Z
# 0  11  2  33
# 1  44  5  66
# 2  77  8  99

# %%
df3 = pd.merge(df1, df2, right_on ='Y', left_on ='B')

# %%
df3
# Out:
#    A  B  C   X  Y   Z
# 0  1  2  3  11  2  33
# 1  4  5  6  44  5  66
# 2  7  8  9  77  8  99
