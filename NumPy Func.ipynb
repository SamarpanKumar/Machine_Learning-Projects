# %%
import numpy as np

# %%
a = np.array([[1,2,3],
                [4,5,6]])

# %%
a.sum(axis=1) #Column
# Out:
# array([ 6, 15])

# %%
a.sum(axis=0) # Rows
# Out:
# array([5, 7, 9])

# %%
b = np.array([[7,8,9],
              [2,8,0]])

# %%
np.dot( a, b.transpose())
# Out:
# array([[ 50,  18],
#        [122,  48]])

# %%
len(dir(np))
# Out:
# 597

# %%
np.cross(a,b)
# Out:
# array([[ -6,  12,  -6],
#        [-48,  12,  22]])

# %%
a = np.array([[11,2,3],
              [4,15,6]])

# %%
np.sort(a, axis=0)
# Out:
# array([[ 4,  2,  3],
#        [11, 15,  6]])

# %%
# %%time
np.sort(a, axis=0, kind='mergesort')
# Out:
# CPU times: user 1.62 ms, sys: 0 ns, total: 1.62 ms
# Wall time: 10.1 ms
# array([[ 4,  2,  3],
#        [11, 15,  6]])

# %%
# %%time
np.sort(a, axis=0, kind ='quicksort')
# Out:
# CPU times: user 321 µs, sys: 949 µs, total: 1.27 ms
# Wall time: 5.43 ms
# array([[ 4,  2,  3],
#        [11, 15,  6]])
