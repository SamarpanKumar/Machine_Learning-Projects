# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5,4),   #6 is the row and 4 is the column.
                  ['A','B','C','D','E'],
                  ['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A -0.441550 -0.781038  0.916551 -0.398863
# B -1.175223 -0.143131 -0.978331  1.026273
# C -0.766901  0.353552 -0.397367  0.117771
# D -1.660450 -0.744801 -1.620261  0.428708
# E  0.784146 -1.355152 -0.501661 -0.610892

# %%
df.shape
# Out:
# (5, 4)

# %%
df.shape
print(df.head())
print(df.tail())
# Out:
#           W         X         Y         Z
# A -0.441550 -0.781038  0.916551 -0.398863
# B -1.175223 -0.143131 -0.978331  1.026273
# C -0.766901  0.353552 -0.397367  0.117771
# D -1.660450 -0.744801 -1.620261  0.428708
# E  0.784146 -1.355152 -0.501661 -0.610892
#           W         X         Y         Z
# A -0.441550 -0.781038  0.916551 -0.398863
# B -1.175223 -0.143131 -0.978331  1.026273
# C -0.766901  0.353552 -0.397367  0.117771
# D -1.660450 -0.744801 -1.620261  0.428708
# E  0.784146 -1.355152 -0.501661 -0.610892

# %%
df.isnull().sum()
# Out:
# W    0
# X    0
# Y    0
# Z    0
# dtype: int64

# %%
print(df.head(1))
df.tail()
# Out:
#          W         X         Y         Z
# A -0.44155 -0.781038  0.916551 -0.398863
#           W         X         Y         Z
# A -0.441550 -0.781038  0.916551 -0.398863
# B -1.175223 -0.143131 -0.978331  1.026273
# C -0.766901  0.353552 -0.397367  0.117771
# D -1.660450 -0.744801 -1.620261  0.428708
# E  0.784146 -1.355152 -0.501661 -0.610892

# %%
df.tail(1)
# Out:
#          W         X         Y         Z
# F -1.31064 -1.366885  0.650363 -0.984541

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df[2:5]
# Out:
#           W         X         Y         Z
# C -0.766901  0.353552 -0.397367  0.117771
# D -1.660450 -0.744801 -1.620261  0.428708
# E  0.784146 -1.355152 -0.501661 -0.610892

# %%
df['W']  # For single column i am geting series
# Out:
# A   -0.441550
# B   -1.175223
# C   -0.766901
# D   -1.660450
# E    0.784146
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['W','Z','X']] # For multiple column i am getting DataFrame
# Out:
#           W         Z         X
# A -0.441550 -0.398863 -0.781038
# B -1.175223  1.026273 -0.143131
# C -0.766901  0.117771  0.353552
# D -1.660450  0.428708 -0.744801
# E  0.784146 -0.610892 -1.355152

# %%
df['new']=df['W']+df['Y']  # Creating new column

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.441550 -0.781038  0.916551 -0.398863  0.475000
# B -1.175223 -0.143131 -0.978331  1.026273 -2.153554
# C -0.766901  0.353552 -0.397367  0.117771 -1.164269
# D -1.660450 -0.744801 -1.620261  0.428708 -3.280711
# E  0.784146 -1.355152 -0.501661 -0.610892  0.282485

# %%
df.drop('F')
# Out:
#           W         X         Y         Z       new
# A  0.268872 -1.022781 -0.200274  0.787819  0.068598
# B  0.947697  0.340363 -2.003648  0.084384 -1.055951
# C  0.015524  0.227397  0.867113 -1.312962  0.882637
# D  0.587481 -0.354042 -0.418551  1.449309  0.168931
# E -0.191598  0.682935 -0.294749  0.392527 -0.486346

# %%
df.drop('F',inplace=True) #Drop Rows

# %%
df.drop('W',axis=1)
# Out:
#           X         Y         Z       new
# A -1.022781 -0.200274  0.787819  0.068598
# B  0.340363 -2.003648  0.084384 -1.055951
# C  0.227397  0.867113 -1.312962  0.882637
# D -0.354042 -0.418551  1.449309  0.168931
# E  0.682935 -0.294749  0.392527 -0.486346

# %%
df.dropna()
df.fillna("value")
# Out:
#           W         X         Y         Z       new
# A  0.268872 -1.022781 -0.200274  0.787819  0.068598
# B  0.947697  0.340363 -2.003648  0.084384 -1.055951
# C  0.015524  0.227397  0.867113 -1.312962  0.882637
# D  0.587481 -0.354042 -0.418551  1.449309  0.168931
# E -0.191598  0.682935 -0.294749  0.392527 -0.486346

# %%
df.drop('W',axis=1,inplace=True)#df.drop('new',axis=1,inplace=True)  By this it will permanentely delete the value

# %%
# df.shape
df.isnull().sum()
# df.dropna()
# df.fillna("somevalue")
# Out:
# X      0
# Y      0
# Z      0
# new    0
# dtype: int64

# %%
df.drop('new',axis=1) # For Removing Column axis one refer to column or axis 0 refer to index
# Out:
#           X         Y         Z
# A -1.022781 -0.200274  0.787819
# B  0.340363 -2.003648  0.084384
# C  0.227397  0.867113 -1.312962
# D -0.354042 -0.418551  1.449309
# E  0.682935 -0.294749  0.392527

# %%
# df.drop('F',axis=0)  # Or you can write df.drop('F') this will also work

# %%
df['A']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c31f9b0c4302> in <cell line: 1>()
# ----> 1 df['A']
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (5, 4)

# %%
#Select Rows below , we have two ways by labels with loc() method or by numerical indexing using iloc() method

# %%
#df['A']
df.loc['A']  # First Way
# Out:
# W    1.090720
# X    0.293684
# Y    0.036449
# Z    0.404255
# Name: A, dtype: float64

# %%
df.iloc[1] # Second Way
# Out:
# X      0.340363
# Y     -2.003648
# Z      0.084384
# new   -1.055951
# Name: B, dtype: float64

# %%
df.loc['B','Y']
df[0:4]
df>0

df[df>0] [['Y','Z']]

s=df[df>0]
s['Y']
# Out:
# A         NaN
# B         NaN
# C    0.867113
# D         NaN
# E         NaN
# Name: Y, dtype: float64

# %%
df.loc[['A','B'],['Y']]
# Out:
#           Y
# A -0.200274
# B -2.003648

# %%
s=df[ df>0 ]
s['X']
#OR
df[df>0]['X']
# Out:
# A         NaN
# B    0.340363
# C    0.227397
# D         NaN
# E    0.682935
# Name: X, dtype: float64

# %%
df[df['Y']>0]['X']
# Out:
# C    0.227397
# Name: X, dtype: float64

# %%
s=df[df['Y']>0 ]

s['X']
# Out:
# C    0.227397
# Name: X, dtype: float64

# %%
sd=df[df['X']>0]
sd
# Out:
#           X         Y         Z       new
# B  0.340363 -2.003648  0.084384 -1.055951
# C  0.227397  0.867113 -1.312962  0.882637
# E  0.682935 -0.294749  0.392527 -0.486346

# %%
sd[['Y','Z']]
# Out:
#           Y         Z
# B -2.003648  0.084384
# C  0.867113 -1.312962
# E -0.294749  0.392527

# %%
df[df['X']>0][['Y','Z']]
# Out:
#           Y         Z
# B -2.003648  0.084384
# C  0.867113 -1.312962
# E -0.294749  0.392527

# %%
df[ df['X']>0 ]['Y']
# Out:
# B   -2.003648
# C    0.867113
# E   -0.294749
# Name: Y, dtype: float64

# %%
df>0

# %%
df[df>0]

# %%
df['W']>0

# %%
df[ df['W']>0 ]

# %%
df[ df['W']>0 ][['Y','Z']]

# %%
resultdf=df[df['W']>0]

# %%
resultdf['X']

# %%
newresult=resultdf['X'] # Multi Step 1

# %%
newresult #multi step 2

# %%
df[df['W']>0]['X'] # Single Step

# %%
#Multiple step again below

# %%
boolser=df['Y']>0
result=df[boolser]
result
mycols=['Y','X']
result[mycols]

# %%
#Single step

# %%
df[ df['Y']>0 ] [['Y','X']]

# %%
df1=pd.read_csv('/content/sample_data/california_housing_test.csv')
df1
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df1.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame
